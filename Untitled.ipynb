# %%
import urllib.request, urllib.error, urllib.parse
import json
import io
import time

urlroot = 'https://api.scryfall.com/cards/search?include_extras=true&include_variations=true&order=set&q=e%3A' 
set_data = []


setcodes = ['lrw', 'mor']
#['lrw', 'mor', 'shm', 'eve']

for code in setcodes:
    scryurl = urlroot + code + '&unique=prints'
    #print(scryurl)
    searchurl = urllib.parse.quote(scryurl, safe=':/=?+%&')
    #print(searchurl)
    link = urllib.request.urlopen(searchurl)
    jfile = link.read().decode()
    try:
        cards = json.loads(jfile)
    except:
        print('Error with json', cardurl)
        continue
    time.sleep(1.5)
    cards = cards['data']
    set_data.append(cards)
    time.sleep(1.5)
    print('got cards for ' + code)

print(set_data)
# Out:
# got cards for lrw
# got cards for mor
# [[{'object': 'card', 'id': '2a1470a6-d09d-4a2a-84a6-d56e32ed237a', 'oracle_id': 'dfb5f660-fd8b-4b7b-934c-6a71cd182f15', 'multiverse_ids': [140233], 'mtgo_id': 28479, 'mtgo_foil_id': 28480, 'tcgplayer_id': 15408, 'cardmarket_id': 17742, 'name': 'Ajani Goldmane', 'lang': 'en', 'released_at': '2007-10-12', 'uri': 'https://api.scryfall.com/cards/2a1470a6-d09d-4a2a-84a6-d56e32ed237a', 'scryfall_uri': 'https://scryfall.com/card/lrw/1/ajani-goldmane?utm_source=api', 'layout': 'normal', 'highres_image': True, 'image_status': 'highres_scan', 'image_uris': {'small': 'https://cards.scryfall.io/small/front/2/a/2a1470a6-d09d-4a2a-84a6-d56e32ed237a.jpg?1562342454', 'normal': 'https://cards.scryfall.io/normal/front/2/a/2a1470a6-d09d-4a2a-84a6-d56e32ed237a.jpg?1562342454', 'large': 'https://cards.scryfall.io/large/front/2/a/2a1470a6-d09d-4a2a-84a6-d56e32ed237a.jpg?1562342454', 'png': 'https://cards.scryfall.io/png/front/2/a/2a1470a6-d09d-4a2a-84a6-d56e32ed237a.png?1562342454', 'art_crop': 'https://cards.scryfall.io/art_crop/front/2/a/2a1470a6-d09d-4a2a-84a6-d56e32ed237a.jpg?1562342454', 'border_crop': 'https://cards.scryfall.io/border_crop/front/2/a/2a1470a6-d09d-4a2a-84a6-d56e32ed237a.jpg?1562342454'}, 'mana_cost': '{2}{W}{W}', 'cmc': 4.0, 'type_line': 'Legendary Planeswalker — Ajani', 'oracle_text': '+1: You gain 2 life.\n−1: Put a +1/+1 counter on each creature you control. Those creatures gain vigilance until end of turn.\n−6: Create a white Avatar creature token. It has "This token\'s power and toughness are each equal to your life total."', 'loyalty': '4', 'colors': ['W'], 'color_identity': ['W'], 'keywords': [], 'all_parts': [{'object': 'related_card', 'id': 'f669cb99-be79-413b-8266-1dfd6a15cb41', 'component': 'token', 'name': 'Avatar', 'type_line': 'Token Creature — Avatar', 'uri': 'https://api.scryfall.com/cards/f669cb99-be79-413b-8266-1dfd6a15cb41'}, {'object': 'related_card', 'id': '2a1470a6-d09d-4a2a-84a6-d56e32ed237a', 'component': 'combo_piece', 'name': 'Ajani Goldmane', 'type_line': 'Legendary Planeswalker — Ajani', 'uri': 'https://api.scryfall.com/cards/2a1470a6-d09d-4a2a-84a6-d56e32ed237a'}], 'legalities': {'standard': 'not_legal', 'future': 'not_legal', 'historic': 'not_legal', 'timeless': 'not_legal', 'gladiator': 'not_legal', 'pioneer': 'not_legal', 'modern': 'legal', 'legacy': 'legal', 'pauper': 'not_legal', 'vintage': 'legal', 'penny': 'legal', 'commander': 'legal', 'oathbreaker': 'legal', 'standardbrawl': 'not_legal', 'brawl': 'not_legal', 'alchemy': 'not_legal', 'paupercommander': 'not_legal', 'duel': 'legal', 'oldschool': 'not_legal', 'premodern': 'not_legal', 'predh': 'legal'}, 'games': ['paper', 'mtgo'], 'reserved': False, 'game_changer': False, 'foil': True, 'nonfoil': True, 'finishes': ['nonfoil', 'foil'], 'oversized': False, 'promo': False, 'reprint': False, 'variation': False, 'set_id': '30ec97cb-dca9-4bf4-a98b-310f9d8ceaff', 'set': 'lrw', 'set_name': 'Lorwyn', 'set_type': 'expansion', 'set_uri': 'https://api.scryfall.com/sets/30ec97cb-dca9-4bf4-a98b-310f9d8ceaff', 'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Alrw&unique=prints', 'scryfall_set_uri': 'https://scryfall.com/sets/lrw?utm_source=api', 'rulings_uri': 'https://api.scryfall.com/cards/2a1470a6-d09d-4a2a-84a6-d56e32ed237a/rulings', 'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3Adfb5f660-fd8b-4b7b-934c-6a71cd182f15&unique=prints', 'collector_number': '1', 'digital': False, 'rarity': 'rare', 'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7', 'artist': 'Aleksi Briclot', 'artist_ids': ['5e470014-31cb-41b0-b054-e23374484449'], 'illustration_id': 'a5e80dde-69a4-43ca-bd4e-d1de5b852c53', 'border_color': 'black', 'frame': '2003', 'full_art': False, 'textless': False, 'booster': True, 'story_spotlight': False, 'edhrec_rank': 10168, 'penny_rank': 2892, 'prices': {'usd': '7.23', 'usd_foil': '21.41', 'usd_etched': None, 'eur': '2.86', 'eur_foil': '12.28', 'tix': '0.02'}, 'related_uris': {'gathere ...
